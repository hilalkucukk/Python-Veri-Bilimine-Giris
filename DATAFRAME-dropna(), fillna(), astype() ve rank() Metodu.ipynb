# %%
import pandas as pd

# %%
nüfus=pd.read_csv("dünyanüfusu.csv")
nüfus
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0         1.0                     China  1,415,045,928               0.39 %
# 1         2.0                     India  1,354,051,854               1.11 %
# 2         3.0                      U.S.    326,766,748               0.71 %
# 3         4.0                 Indonesia    266,794,980               1.06 %
# 4         5.0                    Brazil    210,867,954               0.75 %
# 5         6.0                  Pakistan    200,813,818               1.93 %
# 6         7.0                   Nigeria    195,875,237               2.61 %
# 7         8.0                Bangladesh    166,368,149               1.03 %
# 8         9.0                    Russia    143,964,709              -0.02 %
# 9        10.0                    Mexico    130,759,074               1.24 %
# 10       11.0                     Japan    127,185,332              -0.23 %
# ...

# %%
nüfus.dropna(how="any")
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0         1.0                     China  1,415,045,928               0.39 %
# 1         2.0                     India  1,354,051,854               1.11 %
# 2         3.0                      U.S.    326,766,748               0.71 %
# 3         4.0                 Indonesia    266,794,980               1.06 %
# 4         5.0                    Brazil    210,867,954               0.75 %
# 5         6.0                  Pakistan    200,813,818               1.93 %
# 6         7.0                   Nigeria    195,875,237               2.61 %
# 7         8.0                Bangladesh    166,368,149               1.03 %
# 8         9.0                    Russia    143,964,709              -0.02 %
# 9        10.0                    Mexico    130,759,074               1.24 %
# 10       11.0                     Japan    127,185,332              -0.23 %
# ...

# %%
nüfus.dropna(how="all")
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0         1.0                     China  1,415,045,928               0.39 %
# 1         2.0                     India  1,354,051,854               1.11 %
# 2         3.0                      U.S.    326,766,748               0.71 %
# 3         4.0                 Indonesia    266,794,980               1.06 %
# 4         5.0                    Brazil    210,867,954               0.75 %
# 5         6.0                  Pakistan    200,813,818               1.93 %
# 6         7.0                   Nigeria    195,875,237               2.61 %
# 7         8.0                Bangladesh    166,368,149               1.03 %
# 8         9.0                    Russia    143,964,709              -0.02 %
# 9        10.0                    Mexico    130,759,074               1.24 %
# 10       11.0                     Japan    127,185,332              -0.23 %
# ...

# %%
nüfus.dropna(subset=["Doğum oranı"])
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0         1.0                     China  1,415,045,928               0.39 %
# 1         2.0                     India  1,354,051,854               1.11 %
# 2         3.0                      U.S.    326,766,748               0.71 %
# 3         4.0                 Indonesia    266,794,980               1.06 %
# 4         5.0                    Brazil    210,867,954               0.75 %
# 5         6.0                  Pakistan    200,813,818               1.93 %
# 6         7.0                   Nigeria    195,875,237               2.61 %
# 7         8.0                Bangladesh    166,368,149               1.03 %
# 8         9.0                    Russia    143,964,709              -0.02 %
# 9        10.0                    Mexico    130,759,074               1.24 %
# 10       11.0                     Japan    127,185,332              -0.23 %
# ...

# %%
nüfus.fillna(1)
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0         1.0                     China  1,415,045,928               0.39 %
# 1         2.0                     India  1,354,051,854               1.11 %
# 2         3.0                      U.S.    326,766,748               0.71 %
# 3         4.0                 Indonesia    266,794,980               1.06 %
# 4         5.0                    Brazil    210,867,954               0.75 %
# 5         6.0                  Pakistan    200,813,818               1.93 %
# 6         7.0                   Nigeria    195,875,237               2.61 %
# 7         8.0                Bangladesh    166,368,149               1.03 %
# 8         9.0                    Russia    143,964,709              -0.02 %
# 9        10.0                    Mexico    130,759,074               1.24 %
# 10       11.0                     Japan    127,185,332              -0.23 %
# ...

# %%
nüfus["Doğum oranı"]
# Out:
# 0      1.6
# 1      2.4
# 2      1.9
# 3      2.5
# 4      1.8
# 5      3.7
# 6      5.7
# 7      2.2
# 8      1.7
# 9      2.3
# 10     1.4
# 11     4.6
# 12     NaN
# 13     3.4
# 14     2.0
# 15     6.4
# 16     1.4
# 17     1.7
# 18     2.1
# 19     NaN
# 20     1.9
# 21     2.0
# 22     1.4
# 23     5.2
# 24     2.6
# 25     2.3
# 26     1.2
# 27     NaN
# 28     1.9
# 29     1.3
#       ...
# 203    NaN
# 204    NaN
# 205    NaN
# 206    NaN
# 207    NaN
# 208    NaN
# 209    NaN
# 210    NaN
# 211    NaN
# 212    NaN
# 213    NaN
# 214    NaN
# 215    NaN
# 216    NaN
# 217    NaN
# 218    NaN
# 219    NaN
# 220    NaN
# 221    NaN
# 222    NaN
# 223    NaN
# 224    NaN
# 225    NaN
# 226    NaN
# 227    NaN
# 228    NaN
# 229    NaN
# 230    NaN
# 231    NaN
# 232    NaN
# Name: Doğum oranı, Length: 233, dtype: float64

# %%
nüfus["Doğum oranı"].fillna(1,inplace=True)
nüfus
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0         1.0                     China  1,415,045,928               0.39 %
# 1         2.0                     India  1,354,051,854               1.11 %
# 2         3.0                      U.S.    326,766,748               0.71 %
# 3         4.0                 Indonesia    266,794,980               1.06 %
# 4         5.0                    Brazil    210,867,954               0.75 %
# 5         6.0                  Pakistan    200,813,818               1.93 %
# 6         7.0                   Nigeria    195,875,237               2.61 %
# 7         8.0                Bangladesh    166,368,149               1.03 %
# 8         9.0                    Russia    143,964,709              -0.02 %
# 9        10.0                    Mexico    130,759,074               1.24 %
# 10       11.0                     Japan    127,185,332              -0.23 %
# ...

# %%
nüfus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233 entries, 0 to 232
# Data columns (total 12 columns):
# Sıralama                232 non-null float64
# Ülke                    232 non-null object
# Nüfüs                   232 non-null object
# Yıllık değişim oranı    232 non-null object
# Yıllık değişim          232 non-null object
# Kişi/km2                232 non-null object
# km2                     232 non-null object
# Göçmen                  200 non-null object
# Doğum oranı             233 non-null float64
# Ortalama yaş            200 non-null float64
# Şehirleşme oranı        225 non-null object
# Dünya nüfus oranı       232 non-null object
# dtypes: float64(3), object(9)
# memory usage: 21.9+ KB

# %%
nüfus["Sıralama"]
# Out:
# 0        1.0
# 1        2.0
# 2        3.0
# 3        4.0
# 4        5.0
# 5        6.0
# 6        7.0
# 7        8.0
# 8        9.0
# 9       10.0
# 10      11.0
# 11      12.0
# 12      13.0
# 13      14.0
# 14      15.0
# 15      16.0
# 16      17.0
# 17      18.0
# 18      19.0
# 19      20.0
# 20      21.0
# 21      22.0
# 22      23.0
# 23      24.0
# 24      25.0
# 25      26.0
# 26      27.0
# 27       NaN
# 28      29.0
# 29      30.0
#        ...
# 203    204.0
# 204    205.0
# 205    206.0
# 206    207.0
# 207    208.0
# 208    209.0
# 209    210.0
# 210    211.0
# 211    212.0
# 212    213.0
# 213    214.0
# 214    215.0
# 215    216.0
# 216    217.0
# 217    218.0
# 218    219.0
# 219    220.0
# 220    221.0
# 221    222.0
# 222    223.0
# 223    224.0
# 224    225.0
# 225    226.0
# 226    227.0
# 227    228.0
# 228    229.0
# 229    230.0
# 230    231.0
# 231    232.0
# 232    233.0
# Name: Sıralama, Length: 233, dtype: float64

# %%
nüfus["Sıralama"]=nüfus["Sıralama"].fillna(1.0)
nüfus
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0         1.0                     China  1,415,045,928               0.39 %
# 1         2.0                     India  1,354,051,854               1.11 %
# 2         3.0                      U.S.    326,766,748               0.71 %
# 3         4.0                 Indonesia    266,794,980               1.06 %
# 4         5.0                    Brazil    210,867,954               0.75 %
# 5         6.0                  Pakistan    200,813,818               1.93 %
# 6         7.0                   Nigeria    195,875,237               2.61 %
# 7         8.0                Bangladesh    166,368,149               1.03 %
# 8         9.0                    Russia    143,964,709              -0.02 %
# 9        10.0                    Mexico    130,759,074               1.24 %
# 10       11.0                     Japan    127,185,332              -0.23 %
# ...

# %%
nüfus["Sıralama"]=nüfus["Sıralama"].astype("int")
nüfus
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0           1                     China  1,415,045,928               0.39 %
# 1           2                     India  1,354,051,854               1.11 %
# 2           3                      U.S.    326,766,748               0.71 %
# 3           4                 Indonesia    266,794,980               1.06 %
# 4           5                    Brazil    210,867,954               0.75 %
# 5           6                  Pakistan    200,813,818               1.93 %
# 6           7                   Nigeria    195,875,237               2.61 %
# 7           8                Bangladesh    166,368,149               1.03 %
# 8           9                    Russia    143,964,709              -0.02 %
# 9          10                    Mexico    130,759,074               1.24 %
# 10         11                     Japan    127,185,332              -0.23 %
# ...

# %%
nüfus.sort_values("Ortalama yaş",ascending=False)
# Out:
#      Sıralama                      Ülke        Nüfüs Yıllık değişim oranı  \
# 22         23                     Italy   59,290,969              -0.12 %
# 16         17                   Germany   82,293,457               0.22 %
# 10         11                     Japan  127,185,332              -0.23 %
# 87         88                  Portugal   10,291,196              -0.37 %
# 177       178                Martinique      385,065               0.04 %
# 140       141                 Lithuania    2,876,475              -0.48 %
# 97         98                   Austria    8,751,820               0.19 %
# 147       148                  Slovenia    2,081,260               0.06 %
# 129       130                   Croatia    4,164,783              -0.59 %
# 104       105                  Bulgaria    7,036,848              -0.67 %
# 103       104                 Hong Kong    7,428,887               0.87 %
# 29         30                     Spain   46,397,452               0.09 %
# ...

# %%
nüfus.sort_values(["Ortalama yaş","km2"],ascending=[False,True])
# Out:
#      Sıralama                      Ülke        Nüfüs Yıllık değişim oranı  \
# 22         23                     Italy   59,290,969              -0.12 %
# 16         17                   Germany   82,293,457               0.22 %
# 10         11                     Japan  127,185,332              -0.23 %
# 177       178                Martinique      385,065               0.04 %
# 87         88                  Portugal   10,291,196              -0.37 %
# 103       104                 Hong Kong    7,428,887               0.87 %
# 104       105                  Bulgaria    7,036,848              -0.67 %
# 83         84                    Greece   11,142,161              -0.16 %
# 189       190           Channel Islands      166,083               0.47 %
# 147       148                  Slovenia    2,081,260               0.06 %
# 29         30                     Spain   46,397,452               0.09 %
# 129       130                   Croatia    4,164,783              -0.59 %
# ...

# %%
nüfus.sort_index()
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0           1                     China  1,415,045,928               0.39 %
# 1           2                     India  1,354,051,854               1.11 %
# 2           3                      U.S.    326,766,748               0.71 %
# 3           4                 Indonesia    266,794,980               1.06 %
# 4           5                    Brazil    210,867,954               0.75 %
# 5           6                  Pakistan    200,813,818               1.93 %
# 6           7                   Nigeria    195,875,237               2.61 %
# 7           8                Bangladesh    166,368,149               1.03 %
# 8           9                    Russia    143,964,709              -0.02 %
# 9          10                    Mexico    130,759,074               1.24 %
# 10         11                     Japan    127,185,332              -0.23 %
# ...

# %%
nüfus.sort_index(ascending=False)
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 232       233                  Holy See            801               1.14 %
# 231       232                   Tokelau          1,319               1.46 %
# 230       231                      Niue          1,624               0.37 %
# 229       230          Falkland Islands          2,922               0.41 %
# 228       229              Saint Helena          4,074               0.62 %
# 227       228                Montserrat          5,203               0.50 %
# 226       227   Saint Pierre & Miquelon          6,342               0.35 %
# 225       226                    Tuvalu         11,287               0.85 %
# 224       225                     Nauru         11,312              -0.41 %
# 223       224           Wallis & Futuna         11,683              -0.76 %
# 222       223                  Anguilla         15,045               0.91 %
# ...

# %%
nüfus=pd.read_csv("dünyanüfusu.csv").dropna(how="any")
nüfus
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0         1.0                     China  1,415,045,928               0.39 %
# 1         2.0                     India  1,354,051,854               1.11 %
# 2         3.0                      U.S.    326,766,748               0.71 %
# 3         4.0                 Indonesia    266,794,980               1.06 %
# 4         5.0                    Brazil    210,867,954               0.75 %
# 5         6.0                  Pakistan    200,813,818               1.93 %
# 6         7.0                   Nigeria    195,875,237               2.61 %
# 7         8.0                Bangladesh    166,368,149               1.03 %
# 8         9.0                    Russia    143,964,709              -0.02 %
# 9        10.0                    Mexico    130,759,074               1.24 %
# 10       11.0                     Japan    127,185,332              -0.23 %
# ...

# %%
nüfus=pd.read_csv("dünyanüfusu.csv").dropna(how="any")
nüfus["Yaş Sıralama"]=nüfus["Ortalama yaş"].rank(ascending=False).astype("int")
nüfus
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0         1.0                     China  1,415,045,928               0.39 %
# 1         2.0                     India  1,354,051,854               1.11 %
# 2         3.0                      U.S.    326,766,748               0.71 %
# 3         4.0                 Indonesia    266,794,980               1.06 %
# 4         5.0                    Brazil    210,867,954               0.75 %
# 5         6.0                  Pakistan    200,813,818               1.93 %
# 6         7.0                   Nigeria    195,875,237               2.61 %
# 7         8.0                Bangladesh    166,368,149               1.03 %
# 8         9.0                    Russia    143,964,709              -0.02 %
# 9        10.0                    Mexico    130,759,074               1.24 %
# 10       11.0                     Japan    127,185,332              -0.23 %
# ...
