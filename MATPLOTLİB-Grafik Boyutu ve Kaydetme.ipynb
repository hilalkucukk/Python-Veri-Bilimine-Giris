# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
x=["1.ABD","2.ÇİN","3.JAPONYA","4.ALMANYA","5.İNGİLTİRE","6.FRANSA"]
y=[20410,14090,5170,4210,2940,2930]
z=[63039,9957,40649,51158,44162,44915]

# %%
f=plt.figure(figsize=(10,6)) #x,y eksenlerinin boyutları
axes=f.add_axes([0,0,1,1])
axes.plot(x,y)
axes.set_xlabel("ÜLKELER")
axes.set_ylabel("MİLLİ GELİR")
axes.set_title("ÜLKELERE GÖRE MİLLİ GELİR")
# Out:
# Text(0.5, 1.0, 'ÜLKELERE GÖRE MİLLİ GELİR')

# %%
fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(13,6))
axes[0].plot(x,y,"b")
axes[0].set_title("Milli Gelir")

axes[1].plot(x,z,"y")
axes[1].set_title("Kişi Başına")

plt.tight_layout()

# %%
fig

# %%
fig.savefig("grafik.png") #bilgisayarakaydetti

# %%
fig=plt.figure(figsize=(10,5))
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,"r",label="milli gelir")
ax.plot(x,z,"y",label="kişi başına")
ax.legend(loc=5) #loc=en iyi nerede duracağını bilgisayara bırakmak istersek '0'yazarız,istemezsek değeri kendimiz veririz.
