# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
x=["1.ABD","2.ÇİN","3.JAPONYA","4.ALMANYA","5.İNGİLTİRE","6.FRANSA"]
y=[20410,14090,5170,4210,2940,2930]
z=[63039,9957,40649,51158,44162,44915]

# %%
f=plt.figure()
axes=f.add_axes([0.1,0.1,0.9,0.9])
axes.plot(x,y,color="red",linewidth=2,linestyle="-",marker="o",markersize=20,markerfacecolor="y",markeredgewidth=4,markeredgecolor="blue",alpha=0.5)
axes.set_xlabel("ÜLKELER")
axes.set_ylabel("MİLLİ GELİR")
axes.set_title("ÜLKELERE GÖRE MİLLİ GELİR")
# Out:
# Text(0.5, 1.0, 'ÜLKELERE GÖRE MİLLİ GELİR')

# %%
f=plt.figure()
axes=f.add_axes([0.1,0.1,0.9,0.9])
axes.plot(x,y,color="red",linewidth=2,linestyle="-")
axes.set_xlabel("ÜLKELER")
axes.set_ylabel("MİLLİ GELİR")
axes.set_title("ÜLKELERE GÖRE MİLLİ GELİR")

axes.set_xlim([2,6])
axes.set_ylim([0,7500])
# Out:
# (0, 7500)
