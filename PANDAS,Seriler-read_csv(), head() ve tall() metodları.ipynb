# %%
import pandas as pd

# %%
ülke=pd.read_csv("ulke.csv")
ülke
# Out:
#                Ülke
# 0               ABD
# 1               Çin
# 2           Japonya
# 3           Almanya
# 4         İngiltere
# 5            Fransa
# 6         Hindistan
# 7            İtalya
# 8          Brezilya
# 9            Kanada
# 10            Rusya
# 11       GÜney Kore
# 12          İspanya
# 13      Avusturalya
# 14          Meksika
# 15        Endonezya
# 16         Hollanda
# 17          Türkiye
# 18  Suudi Arabistan
# 19          İsviçre

# %%
ülke=pd.read_csv("ulke.csv",squeeze=True)
ülke
# Out:
# 0                 ABD
# 1                 Çin
# 2             Japonya
# 3             Almanya
# 4           İngiltere
# 5              Fransa
# 6           Hindistan
# 7              İtalya
# 8            Brezilya
# 9              Kanada
# 10              Rusya
# 11         GÜney Kore
# 12            İspanya
# 13        Avusturalya
# 14            Meksika
# 15          Endonezya
# 16           Hollanda
# 17            Türkiye
# 18    Suudi Arabistan
# 19            İsviçre
# Name: Ülke, dtype: object

# %%
gelir=pd.read_csv("milligelir.csv")
gelir
# Out:
#     Milli Gelir
# 0      20410000
# 1      14090000
# 2       5170000
# 3       4210000
# 4       2940000
# 5       2930000
# 6       2850000
# 7       2180000
# 8       2140000
# 9       1800000
# 10      1720000
# 11      1690000
# 12      1510000
# 13      1500000
# 14      1210000
# 15      1070000
# 16       945000
# 17       910000
# 18       748000
# 19       741000

# %%
gelir.head()
# Out:
#    Milli Gelir
# 0     20410000
# 1     14090000
# 2      5170000
# 3      4210000
# 4      2940000

# %%
gelir.head(10)
# Out:
#    Milli Gelir
# 0     20410000
# 1     14090000
# 2      5170000
# 3      4210000
# 4      2940000
# 5      2930000
# 6      2850000
# 7      2180000
# 8      2140000
# 9      1800000

# %%
gelir.tail()
# Out:
#     Milli Gelir
# 15      1070000
# 16       945000
# 17       910000
# 18       748000
# 19       741000

# %%
gelir.tail(3)
# Out:
#     Milli Gelir
# 17       910000
# 18       748000
# 19       741000
